# %%
import torch
from torch.cuda.
from pathlib import Path
import IPython.display as ipd

from util.util import load_audio, crop_audio
from util.platform import get_torch_device_type
from dance_diffusion.api import RequestHandler, Request, RequestType, ModelType
from diffusion_library.sampler import SamplerType
from diffusion_library.scheduler import SchedulerType

import wandb

import pytorch_lightning as pl
from audio_diffusion.models import DiffusionAttnUnet1D
from train_uncond import DiffusionUncond
from audio_diffusion.audio_lora import AudioLoRAModule, AudioLoRANetwork

# %%
wandb.login()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: gcpage. Use `wandb login --relogin` to force relogin
# True

# %%
debug = True
seed = 0
sample_rate = 16000
chunk_size = 65536

device_type_accelerator = get_torch_device_type()
device_accelerator = torch.device(device_type_accelerator)

# %%
def log_audio_tensor(run, name, audio_tensor, sample_rate):
    table = wandb.Table(columns=['Index', 'Audio'])
    for index, sample in enumerate(audio_tensor.cpu().numpy()):
        audio = wandb.Audio(sample[0], sample_rate=sample_rate)  # Has to be mono
        table.add_data(index, audio)
    run.log({name: table})

# %%
def test_sample(
        model,
        batch_size=8,
        steps=50,
        scheduler=SchedulerType.V_CRASH,
        scheduler_args={
            'sigma_min': 0.1,
            'sigma_max': 50.0,
            'rho': 1.0
        },
        sampler=SamplerType.V_IPLMS,
        sampler_args={'use_tqdm': True},
        callback=None
):
    generator = torch.Generator(device_accelerator)
    generator.manual_seed(seed)
    
    step_list = scheduler.get_step_list(steps, device_accelerator.type, **scheduler_args)#step_list = step_list[:-1] if sampler in [SamplerType.V_PRK, SamplerType.V_PLMS, SamplerType.V_PIE, SamplerType.V_PLMS2, SamplerType.V_IPLMS] else step_list
    
    if SamplerType.is_v_sampler(sampler):
        x_T = torch.randn([batch_size, 2, chunk_size], generator=generator, device=device_accelerator)

    
    return sampler.sample(
        model,
        x_T,
        step_list,
        callback,
        **sampler_args
    ).float()

def preview_batch(generated):
    for ix, gen_sample in enumerate(generated):
        print(f'sample #{ix + 1}')
        display(ipd.Audio(gen_sample.cpu(), rate=sample_rate))

# %% [markdown]
# ## Set up model

# %%
run = wandb.init(project='loraw_dev')
# Out:
# wandb version 0.15.5 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.2
# Run data is saved locally in <code>c:\Users\Griffin\Documents\Github\LoRAW\wandb\run-20230707_134450-yihhtlms</code>
# Syncing run <strong><a href='https://wandb.ai/gcpage/loraw_dev/runs/yihhtlms' target="_blank">usual-jazz-7</a></strong> to <a href='https://wandb.ai/gcpage/loraw_dev' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/gcpage/loraw_dev' target="_blank">https://wandb.ai/gcpage/loraw_dev</a>
#  View run at <a href='https://wandb.ai/gcpage/loraw_dev/runs/yihhtlms' target="_blank">https://wandb.ai/gcpage/loraw_dev/runs/yihhtlms</a>

# %%
# Download model
model_name = 'maestro_16000_65536'
model_artifact = run.use_artifact(f'{model_name}:v0', type='model')
checkpoint_path = Path(model_artifact.download()) / f'{model_name}.ckpt'
# Out:
# wandb: Downloading large artifact maestro_16000_65536:v0, 845.20MB. 1 files...
# wandb:   1 of 1 files downloaded.
# Done. 0:0:2.9

# %%
class Object(object):
    pass

args = Object()
args.sample_size = 65536
args.sample_rate = 16000
args.latent_dim = 0
args.seed = 0
args.ema_decay = 0.95

# checkpoint_path = 'models/maestro_16000_65536.ckpt'

model = DiffusionUncond.load_from_checkpoint(checkpoint_path, map_location=device_accelerator, global_args=args)
batch_baseline = test_sample(model.diffusion)
# Out:
# Lightning automatically upgraded your loaded checkpoint from v1.6.4 to v2.0.4. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file c:\Users\Griffin\Documents\Github\LoRAW\artifacts\maestro_16000_65536-v0\maestro_16000_65536.ckpt`

# %%
preview_batch(batch_baseline)
# Out:
# sample #1
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# sample #2
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# sample #3
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# sample #4
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# sample #5
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# sample #6
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# sample #7
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# sample #8
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
run.finish()

# %%
lora_model = AudioLoRANetwork(model.diffusion)
lora_model.apply_to()
print(lora_model)
batch_empty = test_sample(model.diffusion)
# Out:
# create LoRA for U-Net1D: 72 modules.
# AudioLoRANetwork(
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_2_qkv_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_2_out_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_4_qkv_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_4_out_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_6_qkv_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_6_out_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_2_qkv_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_2_out_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_4_qkv_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_4_out_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_6_qkv_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_6_out_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_2_qkv_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_2_out_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_4_qkv_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_4_out_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_6_qkv_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_6_out_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_2_qkv_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_2_out_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_4_qkv_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_4_out_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_6_qkv_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_6_out_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_2_qkv_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_2_out_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_4_qkv_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_4_out_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_6_qkv_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_6_out_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_2_qkv_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_2_out_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_4_qkv_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_4_out_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_6_qkv_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_6_out_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_9_qkv_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_9_out_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_11_qkv_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_11_out_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_13_qkv_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_13_out_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_9_qkv_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_9_out_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_11_qkv_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_11_out_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_13_qkv_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_13_out_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_9_qkv_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_9_out_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_11_qkv_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_11_out_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_13_qkv_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_13_out_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_9_qkv_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_9_out_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_11_qkv_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_11_out_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_13_qkv_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_13_out_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_9_qkv_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_9_out_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_11_qkv_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_11_out_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_13_qkv_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_13_out_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_9_qkv_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_9_out_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_11_qkv_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_11_out_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_13_qkv_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (lora_unet_net_3_main_7_main_7_main_7_main_7_main_7_main_7_main_7_main_13_out_proj): AudioLoRAModule(
#     (lora_down): Conv1d(512, 4, kernel_size=(1,), stride=(1,), bias=False)
#     (lora_up): Conv1d(4, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
# )
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[65], line 4
#       2 lora_model.apply_to()
#       3 print(lora_model)
# ----> 4 batch_empty = test_sample(model.diffusion)
#
# Cell In[59], line 23, in test_sample(model, batch_size, steps, scheduler, scheduler_args, sampler, sampler_args, callback)
#      20 if SamplerType.is_v_sampler(sampler):
#      21     x_T = torch.randn([batch_size, 2, chunk_size], generator=generator, device=device_accelerator)
# ---> 23 return sampler.sample(
#      24     model,
#      25     x_T,
#      26     step_list,
#      27     callback,
#      28     **sampler_args
#      29 ).float()
#
# File c:\users\griffin\documents\github\sample-diffusion\diffusion_library\sampler.py:107, in SamplerType.sample(self, model_fn, x_t, steps, callback, **sampler_args)
#      98     return vsampling.plms2_sample(
#      99         model_fn,
#     100         x_t,
#    (...)
#     104         callback
#     105     )
#     106 elif self == SamplerType.V_IPLMS:
# --> 107     return vsampling.iplms_sample(
#     108         model_fn,
#     109         x_t,
#     110         steps,
#     111         sampler_args.get('extra_args', {}),
#     112         True,
#     113         callback
#     114     )
#     115 elif self == SamplerType.K_EULER:
#     116     return ksampling.sample_euler(
#     117         model_fn,
#     118         x_t,
#    (...)
#     126         sampler_args.get('s_noise', 1.0)
#     127     )
#
# File c:\Users\Griffin\anaconda3\envs\dd\lib\site-packages\torch\autograd\grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# File c:\Users\Griffin\anaconda3\envs\dd\lib\site-packages\diffusion\sampling.py:305, in iplms_sample(model, x, steps, extra_args, is_reverse, callback)
#     303 old_eps = []
#     304 for i in trange(len(steps) - 1, disable=None):
# --> 305     x, eps, pred = iplms_step(model_fn, x, old_eps, steps[i] * ts, steps[i + 1] * ts, extra_args)
#     306     if len(old_eps) >= 3:
#     307         old_eps.pop(0)
#
# File c:\Users\Griffin\anaconda3\envs\dd\lib\site-packages\diffusion\sampling.py:281, in iplms_step(model, x, old_eps, t_1, t_2, extra_args)
#     279 def iplms_step(model, x, old_eps, t_1, t_2, extra_args):
#     280     eps_model_fn = make_eps_model_fn(model)
# --> 281     eps = eps_model_fn(x, t_1, **extra_args)
#     282     if len(old_eps) == 0:
#     283         eps_prime = eps
#
# File c:\Users\Griffin\anaconda3\envs\dd\lib\site-packages\diffusion\sampling.py:143, in make_eps_model_fn.<locals>.eps_model_fn(x, t, **extra_args)
#     141 def eps_model_fn(x, t, **extra_args):
#     142     alphas, sigmas = utils.t_to_alpha_sigma(t)
# --> 143     v = model(x, t, **extra_args)
#     144     eps = x * utils.append_dims(sigmas, x.ndim) + v * utils.append_dims(alphas, x.ndim)
#     145     return eps
#
# File c:\Users\Griffin\anaconda3\envs\dd\lib\site-packages\diffusion\sampling.py:152, in make_autocast_model_fn.<locals>.autocast_model_fn(*args, **kwargs)
#     150 def autocast_model_fn(*args, **kwargs):
#     151     with torch.cuda.amp.autocast(enabled):
# --> 152         return model(*args, **kwargs).float()
#
# File c:\Users\Griffin\anaconda3\envs\dd\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\Griffin\Documents\Github\LoRAW\audio_diffusion\models.py:82, in DiffusionAttnUnet1D.forward(self, input, t, cond)
#      79     cond = F.interpolate(cond, (input.shape[2], ), mode='linear', align_corners=False)
#      80     inputs.append(cond)
# ---> 82 return self.net(torch.cat(inputs, dim=1))
#
# File c:\Users\Griffin\anaconda3\envs\dd\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\Griffin\anaconda3\envs\dd\lib\site-packages\torch\nn\modules\container.py:139, in Sequential.forward(self, input)
#     137 def forward(self, input):
#     138     for module in self:
# --> 139         input = module(input)
#     140     return input
#
# File c:\Users\Griffin\anaconda3\envs\dd\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\Griffin\Documents\Github\LoRAW\audio_diffusion\blocks.py:55, in SkipBlock.forward(self, input)
#      54 def forward(self, input):
# ---> 55     return torch.cat([self.main(input), input], dim=1)
#
#     [... skipping similar frames: Module._call_impl at line 1130 (1 times)]
#
# File c:\Users\Griffin\anaconda3\envs\dd\lib\site-packages\torch\nn\modules\container.py:139, in Sequential.forward(self, input)
#     137 def forward(self, input):
#     138     for module in self:
# --> 139         input = module(input)
#     140     return input
#
#     [... skipping similar frames: Module._call_impl at line 1130 (1 times)]
#
# File c:\Users\Griffin\Documents\Github\LoRAW\audio_diffusion\blocks.py:55, in SkipBlock.forward(self, input)
#      54 def forward(self, input):
# ---> 55     return torch.cat([self.main(input), input], dim=1)
#
#     [... skipping similar frames: Module._call_impl at line 1130 (12 times), Sequential.forward at line 139 (6 times), SkipBlock.forward at line 55 (5 times)]
#
# File c:\Users\Griffin\Documents\Github\LoRAW\audio_diffusion\blocks.py:55, in SkipBlock.forward(self, input)
#      54 def forward(self, input):
# ---> 55     return torch.cat([self.main(input), input], dim=1)
#
#     [... skipping similar frames: Module._call_impl at line 1130 (1 times)]
#
# File c:\Users\Griffin\anaconda3\envs\dd\lib\site-packages\torch\nn\modules\container.py:139, in Sequential.forward(self, input)
#     137 def forward(self, input):
#     138     for module in self:
# --> 139         input = module(input)
#     140     return input
#
# File c:\Users\Griffin\anaconda3\envs\dd\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\Griffin\Documents\Github\LoRAW\audio_diffusion\blocks.py:40, in SelfAttention1d.forward(self, input)
#      38 def forward(self, input):
#      39     n, c, s = input.shape
# ---> 40     qkv = self.qkv_proj(self.norm(input))
#      41     qkv = qkv.view(
#      42         [n, self.n_head * 3, c // self.n_head, s]).transpose(2, 3)
#      43     q, k, v = qkv.chunk(3, dim=1)
#
# File c:\Users\Griffin\anaconda3\envs\dd\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\Griffin\Documents\Github\LoRAW\audio_diffusion\audio_lora.py:69, in AudioLoRAModule.forward(self, x)
#      68 def forward(self, x):
# ---> 69     orig_forwarded = self.orig_forward(x)
#      71     # module dropout
#      72     if self.module_dropout is not None and self.training:
#
# File c:\Users\Griffin\Documents\Github\LoRAW\audio_diffusion\audio_lora.py:69, in AudioLoRAModule.forward(self, x)
#      68 def forward(self, x):
# ---> 69     orig_forwarded = self.orig_forward(x)
#      71     # module dropout
#      72     if self.module_dropout is not None and self.training:
#
#     [... skipping similar frames: AudioLoRAModule.forward at line 69 (6 times)]
#
# File c:\Users\Griffin\Documents\Github\LoRAW\audio_diffusion\audio_lora.py:69, in AudioLoRAModule.forward(self, x)
#      68 def forward(self, x):
# ---> 69     orig_forwarded = self.orig_forward(x)
#      71     # module dropout
#      72     if self.module_dropout is not None and self.training:
#
# File c:\Users\Griffin\Documents\Github\LoRAW\audio_diffusion\audio_lora.py:76, in AudioLoRAModule.forward(self, x)
#      73     if torch.rand(1) < self.module_dropout:
#      74         return orig_forwarded
# ---> 76 lx = self.lora_down(x)
#      78 # normal dropout
#      79 if self.dropout is not None and self.training:
#
# File c:\Users\Griffin\anaconda3\envs\dd\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\Griffin\anaconda3\envs\dd\lib\site-packages\torch\nn\modules\conv.py:307, in Conv1d.forward(self, input)
#     306 def forward(self, input: Tensor) -> Tensor:
# --> 307     return self._conv_forward(input, self.weight, self.bias)
#
# File c:\Users\Griffin\anaconda3\envs\dd\lib\site-packages\torch\nn\modules\conv.py:303, in Conv1d._conv_forward(self, input, weight, bias)
#     299 if self.padding_mode != 'zeros':
#     300     return F.conv1d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     301                     weight, bias, self.stride,
#     302                     _single(0), self.dilation, self.groups)
# --> 303 return F.conv1d(input, weight, bias, self.stride,
#     304                 self.padding, self.dilation, self.groups)
#
# RuntimeError: Input type (torch.cuda.HalfTensor) and weight type (torch.FloatTensor) should be the same

# %%
preview_batch(batch_empty)
# Out:
# DiffusionUncond(
#   (diffusion): DiffusionAttnUnet1D(
#     (timestep_embed): FourierFeatures()
#     (net): Sequential(
#       (0): ResConvBlock(
#         (main): Sequential(
#           (0): Conv1d(18, 128, kernel_size=(5,), stride=(1,), padding=(2,))
#           (1): GroupNorm(1, 128, eps=1e-05, affine=True)
#           (2): GELU(approximate=none)
#           (3): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,))
#           (4): GroupNorm(1, 128, eps=1e-05, affine=True)
#           (5): GELU(approximate=none)
#         )
#         (skip): Conv1d(18, 128, kernel_size=(1,), stride=(1,), bias=False)
#       )
#       (1): ResConvBlock(
#         (main): Sequential(
#           (0): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,))
#           (1): GroupNorm(1, 128, eps=1e-05, affine=True)
#           (2): GELU(approximate=none)
#           (3): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,))
#           (4): GroupNorm(1, 128, eps=1e-05, affine=True)
#           (5): GELU(approximate=none)
#         )
#         (skip): Identity()
#       )
#       (2): ResConvBlock(
#         (main): Sequential(
#           (0): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,))
#           (1): GroupNorm(1, 128, eps=1e-05, affine=True)
#           (2): GELU(approximate=none)
#           (3): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,))
#           (4): GroupNorm(1, 128, eps=1e-05, affine=True)
#           (5): GELU(approximate=none)
#         )
#         (skip): Identity()
#       )
#       (3): SkipBlock(
#         (main): Sequential(
#           (0): Downsample1d()
#           (1): ResConvBlock(
#             (main): Sequential(
#               (0): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,))
#               (1): GroupNorm(1, 128, eps=1e-05, affine=True)
#               (2): GELU(approximate=none)
#               (3): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,))
#               (4): GroupNorm(1, 128, eps=1e-05, affine=True)
#               (5): GELU(approximate=none)
#             )
#             (skip): Identity()
#           )
#           (2): Identity()
#           (3): ResConvBlock(
#             (main): Sequential(
#               (0): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,))
#               (1): GroupNorm(1, 128, eps=1e-05, affine=True)
#               (2): GELU(approximate=none)
#               (3): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,))
#               (4): GroupNorm(1, 128, eps=1e-05, affine=True)
#               (5): GELU(approximate=none)
#             )
#             (skip): Identity()
#           )
#           (4): Identity()
#           (5): ResConvBlock(
#             (main): Sequential(
#               (0): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,))
#               (1): GroupNorm(1, 128, eps=1e-05, affine=True)
#               (2): GELU(approximate=none)
#               (3): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,))
#               (4): GroupNorm(1, 128, eps=1e-05, affine=True)
#               (5): GELU(approximate=none)
#             )
#             (skip): Identity()
#           )
#           (6): Identity()
#           (7): SkipBlock(
#             (main): Sequential(
#               (0): Downsample1d()
#               (1): ResConvBlock(
#                 (main): Sequential(
#                   (0): Conv1d(128, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#                   (1): GroupNorm(1, 256, eps=1e-05, affine=True)
#                   (2): GELU(approximate=none)
#                   (3): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#                   (4): GroupNorm(1, 256, eps=1e-05, affine=True)
#                   (5): GELU(approximate=none)
#                 )
#                 (skip): Conv1d(128, 256, kernel_size=(1,), stride=(1,), bias=False)
#               )
#               (2): Identity()
#               (3): ResConvBlock(
#                 (main): Sequential(
#                   (0): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#                   (1): GroupNorm(1, 256, eps=1e-05, affine=True)
#                   (2): GELU(approximate=none)
#                   (3): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#                   (4): GroupNorm(1, 256, eps=1e-05, affine=True)
#                   (5): GELU(approximate=none)
#                 )
#                 (skip): Identity()
#               )
#               (4): Identity()
#               (5): ResConvBlock(
#                 (main): Sequential(
#                   (0): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#                   (1): GroupNorm(1, 256, eps=1e-05, affine=True)
#                   (2): GELU(approximate=none)
#                   (3): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#                   (4): GroupNorm(1, 256, eps=1e-05, affine=True)
#                   (5): GELU(approximate=none)
#                 )
#                 (skip): Identity()
#               )
#               (6): Identity()
#               (7): SkipBlock(
#                 (main): Sequential(
#                   (0): Downsample1d()
#                   (1): ResConvBlock(
#                     (main): Sequential(
#                       (0): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#                       (1): GroupNorm(1, 256, eps=1e-05, affine=True)
#                       (2): GELU(approximate=none)
#                       (3): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#                       (4): GroupNorm(1, 256, eps=1e-05, affine=True)
#                       (5): GELU(approximate=none)
#                     )
#                     (skip): Identity()
#                   )
#                   (2): Identity()
#                   (3): ResConvBlock(
#                     (main): Sequential(
#                       (0): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#                       (1): GroupNorm(1, 256, eps=1e-05, affine=True)
#                       (2): GELU(approximate=none)
#                       (3): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#                       (4): GroupNorm(1, 256, eps=1e-05, affine=True)
#                       (5): GELU(approximate=none)
#                     )
#                     (skip): Identity()
#                   )
#                   (4): Identity()
#                   (5): ResConvBlock(
#                     (main): Sequential(
#                       (0): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#                       (1): GroupNorm(1, 256, eps=1e-05, affine=True)
#                       (2): GELU(approximate=none)
#                       (3): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#                       (4): GroupNorm(1, 256, eps=1e-05, affine=True)
#                       (5): GELU(approximate=none)
#                     )
#                     (skip): Identity()
#                   )
#                   (6): Identity()
#                   (7): SkipBlock(
#                     (main): Sequential(
#                       (0): Downsample1d()
#                       (1): ResConvBlock(
#                         (main): Sequential(
#                           (0): Conv1d(256, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                           (1): GroupNorm(1, 512, eps=1e-05, affine=True)
#                           (2): GELU(approximate=none)
#                           (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                           (4): GroupNorm(1, 512, eps=1e-05, affine=True)
#                           (5): GELU(approximate=none)
#                         )
#                         (skip): Conv1d(256, 512, kernel_size=(1,), stride=(1,), bias=False)
#                       )
#                       (2): Identity()
#                       (3): ResConvBlock(
#                         (main): Sequential(
#                           (0): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                           (1): GroupNorm(1, 512, eps=1e-05, affine=True)
#                           (2): GELU(approximate=none)
#                           (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                           (4): GroupNorm(1, 512, eps=1e-05, affine=True)
#                           (5): GELU(approximate=none)
#                         )
#                         (skip): Identity()
#                       )
#                       (4): Identity()
#                       (5): ResConvBlock(
#                         (main): Sequential(
#                           (0): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                           (1): GroupNorm(1, 512, eps=1e-05, affine=True)
#                           (2): GELU(approximate=none)
#                           (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                           (4): GroupNorm(1, 512, eps=1e-05, affine=True)
#                           (5): GELU(approximate=none)
#                         )
#                         (skip): Identity()
#                       )
#                       (6): Identity()
#                       (7): SkipBlock(
#                         (main): Sequential(
#                           (0): Downsample1d()
#                           (1): ResConvBlock(
#                             (main): Sequential(
#                               (0): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                               (1): GroupNorm(1, 512, eps=1e-05, affine=True)
#                               (2): GELU(approximate=none)
#                               (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                               (4): GroupNorm(1, 512, eps=1e-05, affine=True)
#                               (5): GELU(approximate=none)
#                             )
#                             (skip): Identity()
#                           )
#                           (2): Identity()
#                           (3): ResConvBlock(
#                             (main): Sequential(
#                               (0): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                               (1): GroupNorm(1, 512, eps=1e-05, affine=True)
#                               (2): GELU(approximate=none)
#                               (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                               (4): GroupNorm(1, 512, eps=1e-05, affine=True)
#                               (5): GELU(approximate=none)
#                             )
#                             (skip): Identity()
#                           )
#                           (4): Identity()
#                           (5): ResConvBlock(
#                             (main): Sequential(
#                               (0): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                               (1): GroupNorm(1, 512, eps=1e-05, affine=True)
#                               (2): GELU(approximate=none)
#                               (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                               (4): GroupNorm(1, 512, eps=1e-05, affine=True)
#                               (5): GELU(approximate=none)
#                             )
#                             (skip): Identity()
#                           )
#                           (6): Identity()
#                           (7): SkipBlock(
#                             (main): Sequential(
#                               (0): Downsample1d()
#                               (1): ResConvBlock(
#                                 (main): Sequential(
#                                   (0): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                   (1): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                   (2): GELU(approximate=none)
#                                   (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                   (4): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                   (5): GELU(approximate=none)
#                                 )
#                                 (skip): Identity()
#                               )
#                               (2): Identity()
#                               (3): ResConvBlock(
#                                 (main): Sequential(
#                                   (0): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                   (1): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                   (2): GELU(approximate=none)
#                                   (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                   (4): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                   (5): GELU(approximate=none)
#                                 )
#                                 (skip): Identity()
#                               )
#                               (4): Identity()
#                               (5): ResConvBlock(
#                                 (main): Sequential(
#                                   (0): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                   (1): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                   (2): GELU(approximate=none)
#                                   (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                   (4): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                   (5): GELU(approximate=none)
#                                 )
#                                 (skip): Identity()
#                               )
#                               (6): Identity()
#                               (7): SkipBlock(
#                                 (main): Sequential(
#                                   (0): Downsample1d()
#                                   (1): ResConvBlock(
#                                     (main): Sequential(
#                                       (0): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                       (1): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                       (2): GELU(approximate=none)
#                                       (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                       (4): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                       (5): GELU(approximate=none)
#                                     )
#                                     (skip): Identity()
#                                   )
#                                   (2): Identity()
#                                   (3): ResConvBlock(
#                                     (main): Sequential(
#                                       (0): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                       (1): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                       (2): GELU(approximate=none)
#                                       (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                       (4): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                       (5): GELU(approximate=none)
#                                     )
#                                     (skip): Identity()
#                                   )
#                                   (4): Identity()
#                                   (5): ResConvBlock(
#                                     (main): Sequential(
#                                       (0): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                       (1): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                       (2): GELU(approximate=none)
#                                       (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                       (4): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                       (5): GELU(approximate=none)
#                                     )
#                                     (skip): Identity()
#                                   )
#                                   (6): Identity()
#                                   (7): SkipBlock(
#                                     (main): Sequential(
#                                       (0): Downsample1d()
#                                       (1): ResConvBlock(
#                                         (main): Sequential(
#                                           (0): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                           (1): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                           (2): GELU(approximate=none)
#                                           (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                           (4): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                           (5): GELU(approximate=none)
#                                         )
#                                         (skip): Identity()
#                                       )
#                                       (2): SelfAttention1d(
#                                         (norm): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                         (qkv_proj): Conv1d(512, 1536, kernel_size=(1,), stride=(1,))
#                                         (out_proj): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#                                         (dropout): Dropout(p=0.0, inplace=True)
#                                       )
#                                       (3): ResConvBlock(
#                                         (main): Sequential(
#                                           (0): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                           (1): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                           (2): GELU(approximate=none)
#                                           (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                           (4): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                           (5): GELU(approximate=none)
#                                         )
#                                         (skip): Identity()
#                                       )
#                                       (4): SelfAttention1d(
#                                         (norm): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                         (qkv_proj): Conv1d(512, 1536, kernel_size=(1,), stride=(1,))
#                                         (out_proj): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#                                         (dropout): Dropout(p=0.0, inplace=True)
#                                       )
#                                       (5): ResConvBlock(
#                                         (main): Sequential(
#                                           (0): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                           (1): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                           (2): GELU(approximate=none)
#                                           (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                           (4): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                           (5): GELU(approximate=none)
#                                         )
#                                         (skip): Identity()
#                                       )
#                                       (6): SelfAttention1d(
#                                         (norm): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                         (qkv_proj): Conv1d(512, 1536, kernel_size=(1,), stride=(1,))
#                                         (out_proj): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#                                         (dropout): Dropout(p=0.0, inplace=True)
#                                       )
#                                       (7): SkipBlock(
#                                         (main): Sequential(
#                                           (0): Downsample1d()
#                                           (1): ResConvBlock(
#                                             (main): Sequential(
#                                               (0): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                               (1): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                               (2): GELU(approximate=none)
#                                               (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                               (4): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                               (5): GELU(approximate=none)
#                                             )
#                                             (skip): Identity()
#                                           )
#                                           (2): SelfAttention1d(
#                                             (norm): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                             (qkv_proj): Conv1d(512, 1536, kernel_size=(1,), stride=(1,))
#                                             (out_proj): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#                                             (dropout): Dropout(p=0.0, inplace=True)
#                                           )
#                                           (3): ResConvBlock(
#                                             (main): Sequential(
#                                               (0): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                               (1): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                               (2): GELU(approximate=none)
#                                               (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                               (4): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                               (5): GELU(approximate=none)
#                                             )
#                                             (skip): Identity()
#                                           )
#                                           (4): SelfAttention1d(
#                                             (norm): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                             (qkv_proj): Conv1d(512, 1536, kernel_size=(1,), stride=(1,))
#                                             (out_proj): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#                                             (dropout): Dropout(p=0.0, inplace=True)
#                                           )
#                                           (5): ResConvBlock(
#                                             (main): Sequential(
#                                               (0): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                               (1): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                               (2): GELU(approximate=none)
#                                               (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                               (4): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                               (5): GELU(approximate=none)
#                                             )
#                                             (skip): Identity()
#                                           )
#                                           (6): SelfAttention1d(
#                                             (norm): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                             (qkv_proj): Conv1d(512, 1536, kernel_size=(1,), stride=(1,))
#                                             (out_proj): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#                                             (dropout): Dropout(p=0.0, inplace=True)
#                                           )
#                                           (7): SkipBlock(
#                                             (main): Sequential(
#                                               (0): Downsample1d()
#                                               (1): ResConvBlock(
#                                                 (main): Sequential(
#                                                   (0): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                                   (1): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                                   (2): GELU(approximate=none)
#                                                   (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                                   (4): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                                   (5): GELU(approximate=none)
#                                                 )
#                                                 (skip): Identity()
#                                               )
#                                               (2): SelfAttention1d(
#                                                 (norm): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                                 (qkv_proj): Conv1d(512, 1536, kernel_size=(1,), stride=(1,))
#                                                 (out_proj): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#                                                 (dropout): Dropout(p=0.0, inplace=True)
#                                               )
#                                               (3): ResConvBlock(
#                                                 (main): Sequential(
#                                                   (0): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                                   (1): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                                   (2): GELU(approximate=none)
#                                                   (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                                   (4): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                                   (5): GELU(approximate=none)
#                                                 )
#                                                 (skip): Identity()
#                                               )
#                                               (4): SelfAttention1d(
#                                                 (norm): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                                 (qkv_proj): Conv1d(512, 1536, kernel_size=(1,), stride=(1,))
#                                                 (out_proj): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#                                                 (dropout): Dropout(p=0.0, inplace=True)
#                                               )
#                                               (5): ResConvBlock(
#                                                 (main): Sequential(
#                                                   (0): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                                   (1): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                                   (2): GELU(approximate=none)
#                                                   (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                                   (4): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                                   (5): GELU(approximate=none)
#                                                 )
#                                                 (skip): Identity()
#                                               )
#                                               (6): SelfAttention1d(
#                                                 (norm): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                                 (qkv_proj): Conv1d(512, 1536, kernel_size=(1,), stride=(1,))
#                                                 (out_proj): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#                                                 (dropout): Dropout(p=0.0, inplace=True)
#                                               )
#                                               (7): SkipBlock(
#                                                 (main): Sequential(
#                                                   (0): Downsample1d()
#                                                   (1): ResConvBlock(
#                                                     (main): Sequential(
#                                                       (0): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                                       (1): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                                       (2): GELU(approximate=none)
#                                                       (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                                       (4): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                                       (5): GELU(approximate=none)
#                                                     )
#                                                     (skip): Identity()
#                                                   )
#                                                   (2): SelfAttention1d(
#                                                     (norm): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                                     (qkv_proj): Conv1d(512, 1536, kernel_size=(1,), stride=(1,))
#                                                     (out_proj): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#                                                     (dropout): Dropout(p=0.0, inplace=True)
#                                                   )
#                                                   (3): ResConvBlock(
#                                                     (main): Sequential(
#                                                       (0): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                                       (1): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                                       (2): GELU(approximate=none)
#                                                       (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                                       (4): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                                       (5): GELU(approximate=none)
#                                                     )
#                                                     (skip): Identity()
#                                                   )
#                                                   (4): SelfAttention1d(
#                                                     (norm): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                                     (qkv_proj): Conv1d(512, 1536, kernel_size=(1,), stride=(1,))
#                                                     (out_proj): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#                                                     (dropout): Dropout(p=0.0, inplace=True)
#                                                   )
#                                                   (5): ResConvBlock(
#                                                     (main): Sequential(
#                                                       (0): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                                       (1): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                                       (2): GELU(approximate=none)
#                                                       (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                                       (4): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                                       (5): GELU(approximate=none)
#                                                     )
#                                                     (skip): Identity()
#                                                   )
#                                                   (6): SelfAttention1d(
#                                                     (norm): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                                     (qkv_proj): Conv1d(512, 1536, kernel_size=(1,), stride=(1,))
#                                                     (out_proj): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#                                                     (dropout): Dropout(p=0.0, inplace=True)
#                                                   )
#                                                   (7): SkipBlock(
#                                                     (main): Sequential(
#                                                       (0): Downsample1d()
#                                                       (1): ResConvBlock(
#                                                         (main): Sequential(
#                                                           (0): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                                           (1): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                                           (2): GELU(approximate=none)
#                                                           (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                                           (4): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                                           (5): GELU(approximate=none)
#                                                         )
#                                                         (skip): Identity()
#                                                       )
#                                                       (2): SelfAttention1d(
#                                                         (norm): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                                         (qkv_proj): Conv1d(512, 1536, kernel_size=(1,), stride=(1,))
#                                                         (out_proj): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#                                                         (dropout): Dropout(p=0.0, inplace=True)
#                                                       )
#                                                       (3): ResConvBlock(
#                                                         (main): Sequential(
#                                                           (0): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                                           (1): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                                           (2): GELU(approximate=none)
#                                                           (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                                           (4): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                                           (5): GELU(approximate=none)
#                                                         )
#                                                         (skip): Identity()
#                                                       )
#                                                       (4): SelfAttention1d(
#                                                         (norm): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                                         (qkv_proj): Conv1d(512, 1536, kernel_size=(1,), stride=(1,))
#                                                         (out_proj): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#                                                         (dropout): Dropout(p=0.0, inplace=True)
#                                                       )
#                                                       (5): ResConvBlock(
#                                                         (main): Sequential(
#                                                           (0): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                                           (1): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                                           (2): GELU(approximate=none)
#                                                           (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                                           (4): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                                           (5): GELU(approximate=none)
#                                                         )
#                                                         (skip): Identity()
#                                                       )
#                                                       (6): SelfAttention1d(
#                                                         (norm): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                                         (qkv_proj): Conv1d(512, 1536, kernel_size=(1,), stride=(1,))
#                                                         (out_proj): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#                                                         (dropout): Dropout(p=0.0, inplace=True)
#                                                       )
#                                                       (7): SkipBlock(
#                                                         (main): Sequential(
#                                                           (0): Downsample1d()
#                                                           (1): ResConvBlock(
#                                                             (main): Sequential(
#                                                               (0): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                                               (1): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                                               (2): GELU(approximate=none)
#                                                               (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                                               (4): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                                               (5): GELU(approximate=none)
#                                                             )
#                                                             (skip): Identity()
#                                                           )
#                                                           (2): SelfAttention1d(
#                                                             (norm): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                                             (qkv_proj): Conv1d(512, 1536, kernel_size=(1,), stride=(1,))
#                                                             (out_proj): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#                                                             (dropout): Dropout(p=0.0, inplace=True)
#                                                           )
#                                                           (3): ResConvBlock(
#                                                             (main): Sequential(
#                                                               (0): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                                               (1): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                                               (2): GELU(approximate=none)
#                                                               (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                                               (4): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                                               (5): GELU(approximate=none)
#                                                             )
#                                                             (skip): Identity()
#                                                           )
#                                                           (4): SelfAttention1d(
#                                                             (norm): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                                             (qkv_proj): Conv1d(512, 1536, kernel_size=(1,), stride=(1,))
#                                                             (out_proj): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#                                                             (dropout): Dropout(p=0.0, inplace=True)
#                                                           )
#                                                           (5): ResConvBlock(
#                                                             (main): Sequential(
#                                                               (0): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                                               (1): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                                               (2): GELU(approximate=none)
#                                                               (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                                               (4): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                                               (5): GELU(approximate=none)
#                                                             )
#                                                             (skip): Identity()
#                                                           )
#                                                           (6): SelfAttention1d(
#                                                             (norm): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                                             (qkv_proj): Conv1d(512, 1536, kernel_size=(1,), stride=(1,))
#                                                             (out_proj): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#                                                             (dropout): Dropout(p=0.0, inplace=True)
#                                                           )
#                                                           (7): Identity()
#                                                           (8): ResConvBlock(
#                                                             (main): Sequential(
#                                                               (0): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                                               (1): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                                               (2): GELU(approximate=none)
#                                                               (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                                               (4): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                                               (5): GELU(approximate=none)
#                                                             )
#                                                             (skip): Identity()
#                                                           )
#                                                           (9): SelfAttention1d(
#                                                             (norm): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                                             (qkv_proj): Conv1d(512, 1536, kernel_size=(1,), stride=(1,))
#                                                             (out_proj): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#                                                             (dropout): Dropout(p=0.0, inplace=True)
#                                                           )
#                                                           (10): ResConvBlock(
#                                                             (main): Sequential(
#                                                               (0): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                                               (1): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                                               (2): GELU(approximate=none)
#                                                               (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                                               (4): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                                               (5): GELU(approximate=none)
#                                                             )
#                                                             (skip): Identity()
#                                                           )
#                                                           (11): SelfAttention1d(
#                                                             (norm): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                                             (qkv_proj): Conv1d(512, 1536, kernel_size=(1,), stride=(1,))
#                                                             (out_proj): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
#                                                             (dropout): Dropout(p=0.0, inplace=True)
#                                                           )
#                                                           (12): ResConvBlock(
#                                                             (main): Sequential(
#                                                               (0): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                                               (1): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                                               (2): GELU(approximate=none)
#                                                               (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                                               (4): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                                               (5): GELU(approximate=none)
#                                                             )
#                                                             (skip): Identity()
#                                                           )
#                                                           (13): SelfAttention1d(
#                                                             (norm): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                                             (qkv_proj): Conv1d(512, 1536, kernel_size=(1,), stride=(1,))
#                                                             (out_proj): Conv1d(512, 512, kernel_size=(1,), stride=(1,))
# ...
#                                       (2): GELU(approximate=none)
#                                       (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                       (4): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                       (5): GELU(approximate=none)
#                                     )
#                                     (skip): Conv1d(1024, 512, kernel_size=(1,), stride=(1,), bias=False)
#                                   )
#                                   (9): Identity()
#                                   (10): ResConvBlock(
#                                     (main): Sequential(
#                                       (0): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                       (1): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                       (2): GELU(approximate=none)
#                                       (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                       (4): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                       (5): GELU(approximate=none)
#                                     )
#                                     (skip): Identity()
#                                   )
#                                   (11): Identity()
#                                   (12): ResConvBlock(
#                                     (main): Sequential(
#                                       (0): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                       (1): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                       (2): GELU(approximate=none)
#                                       (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                       (4): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                       (5): GELU(approximate=none)
#                                     )
#                                     (skip): Identity()
#                                   )
#                                   (13): Identity()
#                                   (14): Upsample1d()
#                                 )
#                               )
#                               (8): ResConvBlock(
#                                 (main): Sequential(
#                                   (0): Conv1d(1024, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                   (1): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                   (2): GELU(approximate=none)
#                                   (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                   (4): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                   (5): GELU(approximate=none)
#                                 )
#                                 (skip): Conv1d(1024, 512, kernel_size=(1,), stride=(1,), bias=False)
#                               )
#                               (9): Identity()
#                               (10): ResConvBlock(
#                                 (main): Sequential(
#                                   (0): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                   (1): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                   (2): GELU(approximate=none)
#                                   (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                   (4): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                   (5): GELU(approximate=none)
#                                 )
#                                 (skip): Identity()
#                               )
#                               (11): Identity()
#                               (12): ResConvBlock(
#                                 (main): Sequential(
#                                   (0): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                   (1): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                   (2): GELU(approximate=none)
#                                   (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                                   (4): GroupNorm(1, 512, eps=1e-05, affine=True)
#                                   (5): GELU(approximate=none)
#                                 )
#                                 (skip): Identity()
#                               )
#                               (13): Identity()
#                               (14): Upsample1d()
#                             )
#                           )
#                           (8): ResConvBlock(
#                             (main): Sequential(
#                               (0): Conv1d(1024, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                               (1): GroupNorm(1, 512, eps=1e-05, affine=True)
#                               (2): GELU(approximate=none)
#                               (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                               (4): GroupNorm(1, 512, eps=1e-05, affine=True)
#                               (5): GELU(approximate=none)
#                             )
#                             (skip): Conv1d(1024, 512, kernel_size=(1,), stride=(1,), bias=False)
#                           )
#                           (9): Identity()
#                           (10): ResConvBlock(
#                             (main): Sequential(
#                               (0): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                               (1): GroupNorm(1, 512, eps=1e-05, affine=True)
#                               (2): GELU(approximate=none)
#                               (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                               (4): GroupNorm(1, 512, eps=1e-05, affine=True)
#                               (5): GELU(approximate=none)
#                             )
#                             (skip): Identity()
#                           )
#                           (11): Identity()
#                           (12): ResConvBlock(
#                             (main): Sequential(
#                               (0): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                               (1): GroupNorm(1, 512, eps=1e-05, affine=True)
#                               (2): GELU(approximate=none)
#                               (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                               (4): GroupNorm(1, 512, eps=1e-05, affine=True)
#                               (5): GELU(approximate=none)
#                             )
#                             (skip): Identity()
#                           )
#                           (13): Identity()
#                           (14): Upsample1d()
#                         )
#                       )
#                       (8): ResConvBlock(
#                         (main): Sequential(
#                           (0): Conv1d(1024, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                           (1): GroupNorm(1, 512, eps=1e-05, affine=True)
#                           (2): GELU(approximate=none)
#                           (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                           (4): GroupNorm(1, 512, eps=1e-05, affine=True)
#                           (5): GELU(approximate=none)
#                         )
#                         (skip): Conv1d(1024, 512, kernel_size=(1,), stride=(1,), bias=False)
#                       )
#                       (9): Identity()
#                       (10): ResConvBlock(
#                         (main): Sequential(
#                           (0): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                           (1): GroupNorm(1, 512, eps=1e-05, affine=True)
#                           (2): GELU(approximate=none)
#                           (3): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                           (4): GroupNorm(1, 512, eps=1e-05, affine=True)
#                           (5): GELU(approximate=none)
#                         )
#                         (skip): Identity()
#                       )
#                       (11): Identity()
#                       (12): ResConvBlock(
#                         (main): Sequential(
#                           (0): Conv1d(512, 512, kernel_size=(5,), stride=(1,), padding=(2,))
#                           (1): GroupNorm(1, 512, eps=1e-05, affine=True)
#                           (2): GELU(approximate=none)
#                           (3): Conv1d(512, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#                           (4): GroupNorm(1, 256, eps=1e-05, affine=True)
#                           (5): GELU(approximate=none)
#                         )
#                         (skip): Conv1d(512, 256, kernel_size=(1,), stride=(1,), bias=False)
#                       )
#                       (13): Identity()
#                       (14): Upsample1d()
#                     )
#                   )
#                   (8): ResConvBlock(
#                     (main): Sequential(
#                       (0): Conv1d(512, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#                       (1): GroupNorm(1, 256, eps=1e-05, affine=True)
#                       (2): GELU(approximate=none)
#                       (3): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#                       (4): GroupNorm(1, 256, eps=1e-05, affine=True)
#                       (5): GELU(approximate=none)
#                     )
#                     (skip): Conv1d(512, 256, kernel_size=(1,), stride=(1,), bias=False)
#                   )
#                   (9): Identity()
#                   (10): ResConvBlock(
#                     (main): Sequential(
#                       (0): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#                       (1): GroupNorm(1, 256, eps=1e-05, affine=True)
#                       (2): GELU(approximate=none)
#                       (3): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#                       (4): GroupNorm(1, 256, eps=1e-05, affine=True)
#                       (5): GELU(approximate=none)
#                     )
#                     (skip): Identity()
#                   )
#                   (11): Identity()
#                   (12): ResConvBlock(
#                     (main): Sequential(
#                       (0): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#                       (1): GroupNorm(1, 256, eps=1e-05, affine=True)
#                       (2): GELU(approximate=none)
#                       (3): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#                       (4): GroupNorm(1, 256, eps=1e-05, affine=True)
#                       (5): GELU(approximate=none)
#                     )
#                     (skip): Identity()
#                   )
#                   (13): Identity()
#                   (14): Upsample1d()
#                 )
#               )
#               (8): ResConvBlock(
#                 (main): Sequential(
#                   (0): Conv1d(512, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#                   (1): GroupNorm(1, 256, eps=1e-05, affine=True)
#                   (2): GELU(approximate=none)
#                   (3): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#                   (4): GroupNorm(1, 256, eps=1e-05, affine=True)
#                   (5): GELU(approximate=none)
#                 )
#                 (skip): Conv1d(512, 256, kernel_size=(1,), stride=(1,), bias=False)
#               )
#               (9): Identity()
#               (10): ResConvBlock(
#                 (main): Sequential(
#                   (0): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#                   (1): GroupNorm(1, 256, eps=1e-05, affine=True)
#                   (2): GELU(approximate=none)
#                   (3): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#                   (4): GroupNorm(1, 256, eps=1e-05, affine=True)
#                   (5): GELU(approximate=none)
#                 )
#                 (skip): Identity()
#               )
#               (11): Identity()
#               (12): ResConvBlock(
#                 (main): Sequential(
#                   (0): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#                   (1): GroupNorm(1, 256, eps=1e-05, affine=True)
#                   (2): GELU(approximate=none)
#                   (3): Conv1d(256, 128, kernel_size=(5,), stride=(1,), padding=(2,))
#                   (4): GroupNorm(1, 128, eps=1e-05, affine=True)
#                   (5): GELU(approximate=none)
#                 )
#                 (skip): Conv1d(256, 128, kernel_size=(1,), stride=(1,), bias=False)
#               )
#               (13): Identity()
#               (14): Upsample1d()
#             )
#           )
#           (8): ResConvBlock(
#             (main): Sequential(
#               (0): Conv1d(256, 128, kernel_size=(5,), stride=(1,), padding=(2,))
#               (1): GroupNorm(1, 128, eps=1e-05, affine=True)
#               (2): GELU(approximate=none)
#               (3): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,))
#               (4): GroupNorm(1, 128, eps=1e-05, affine=True)
#               (5): GELU(approximate=none)
#             )
#             (skip): Conv1d(256, 128, kernel_size=(1,), stride=(1,), bias=False)
#           )
#           (9): Identity()
#           (10): ResConvBlock(
#             (main): Sequential(
#               (0): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,))
#               (1): GroupNorm(1, 128, eps=1e-05, affine=True)
#               (2): GELU(approximate=none)
#               (3): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,))
#               (4): GroupNorm(1, 128, eps=1e-05, affine=True)
#               (5): GELU(approximate=none)
#             )
#             (skip): Identity()
#           )
#           (11): Identity()
#           (12): ResConvBlock(
#             (main): Sequential(
#               (0): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,))
#               (1): GroupNorm(1, 128, eps=1e-05, affine=True)
#               (2): GELU(approximate=none)
#               (3): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,))
#               (4): GroupNorm(1, 128, eps=1e-05, affine=True)
#               (5): GELU(approximate=none)
#             )
#             (skip): Identity()
#           )
#           (13): Identity()
#           (14): Upsample1d()
#         )
#       )
#       (4): ResConvBlock(
#         (main): Sequential(
#           (0): Conv1d(256, 128, kernel_size=(5,), stride=(1,), padding=(2,))
#           (1): GroupNorm(1, 128, eps=1e-05, affine=True)
#           (2): GELU(approximate=none)
#           (3): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,))
#           (4): GroupNorm(1, 128, eps=1e-05, affine=True)
#           (5): GELU(approximate=none)
#         )
#         (skip): Conv1d(256, 128, kernel_size=(1,), stride=(1,), bias=False)
#       )
#       (5): ResConvBlock(
#         (main): Sequential(
#           (0): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,))
#           (1): GroupNorm(1, 128, eps=1e-05, affine=True)
#           (2): GELU(approximate=none)
#           (3): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,))
#           (4): GroupNorm(1, 128, eps=1e-05, affine=True)
#           (5): GELU(approximate=none)
#         )
#         (skip): Identity()
#       )
#       (6): ResConvBlock(
#         (main): Sequential(
#           (0): Conv1d(128, 128, kernel_size=(5,), stride=(1,), padding=(2,))
#           (1): GroupNorm(1, 128, eps=1e-05, affine=True)
#           (2): GELU(approximate=none)
#           (3): Conv1d(128, 2, kernel_size=(5,), stride=(1,), padding=(2,))
#           (4): Identity()
#           (5): Identity()
#         )
#         (skip): Conv1d(128, 2, kernel_size=(1,), stride=(1,), bias=False)
#       )
#     )
#   )
# )
